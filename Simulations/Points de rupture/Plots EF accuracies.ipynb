# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Pour patients uniquement, faire un autre notebook ou poursuivre sur ce notebook pour les docteurs ? juste remplacer patient dans pd.read_csv('accuracy patient z0.4 ratio 1.csv') 
# pour les df du début

# %% [markdown]
# ### z fixe

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 1.csv')
df2 = pd.read_csv('accuracy patient z0.4 ratio 2.csv')
df3 = pd.read_csv('accuracy patient z0.4 ratio 3.csv')
df4 = pd.read_csv('accuracy patient z0.4 ratio 4.csv')
df5 = pd.read_csv('accuracy patient z0.4 ratio 5.csv')

exact_accuracy_sparse_z1 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0], df5['sparse'][0] ]
almost_accuracy_sparse_z1 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1], df5['sparse'][1] ]

exact_accuracy_mid_z1 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0], df5['mid'][0] ]
almost_accuracy_mid_z1 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1], df5['mid'][1] ]

exact_accuracy_dense_z1 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0], df5['dense'][0] ]
almost_accuracy_dense_z1 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1], df5['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z1)
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z1)
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z1)
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z1)
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z1)
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z1)

axis[0, 1].set_xlabel('ratio patients/docteurs')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('ratio patients/docteurs')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction du ratio (z = 0.4)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction du ratio (z = 0.4)')

# %%
df1 = pd.read_csv('accuracy patient z0.7 ratio 1.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 2.csv')
df3 = pd.read_csv('accuracy patient z0.7 ratio 3.csv')
df4 = pd.read_csv('accuracy patient z0.7 ratio 4.csv')
df5 = pd.read_csv('accuracy patient z0.7 ratio 5.csv')

exact_accuracy_sparse_z2 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0], df5['sparse'][0] ]
almost_accuracy_sparse_z2 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1], df5['sparse'][1] ]

exact_accuracy_mid_z2 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0], df5['mid'][0] ]
almost_accuracy_mid_z2 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1], df5['mid'][1] ]

exact_accuracy_dense_z2 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0], df5['dense'][0] ]
almost_accuracy_dense_z2 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1], df5['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z2)
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z2)
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z2)
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z2)
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z2)
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z2)

axis[0, 1].set_xlabel('ratio patients/docteurs')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('ratio patients/docteurs')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction du ratio (z = 0.7)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction du ratio (z = 0.7)')

# %%
df1 = pd.read_csv('accuracy patient z1.1 ratio 1.csv')
df2 = pd.read_csv('accuracy patient z1.1 ratio 2.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 3.csv')
df4 = pd.read_csv('accuracy patient z1.1 ratio 4.csv')
df5 = pd.read_csv('accuracy patient z1.1 ratio 5.csv')

exact_accuracy_sparse_z3 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0], df5['sparse'][0] ]
almost_accuracy_sparse_z3 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1], df5['sparse'][1] ]

exact_accuracy_mid_z3 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0], df5['mid'][0] ]
almost_accuracy_mid_z3 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1], df5['mid'][1] ]

exact_accuracy_dense_z3 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0], df5['dense'][0] ]
almost_accuracy_dense_z3 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1], df5['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z3)
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z3)
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z3)
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z3)
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z3)
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z3)

axis[0, 1].set_xlabel('ratio patients/docteurs')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('ratio patients/docteurs')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
# axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction du ratio (z = 1.1)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction du ratio (z = 1.1)')

# %%
df1 = pd.read_csv('accuracy patient zsqrt(2) ratio 1.csv')
df2 = pd.read_csv('accuracy patient zsqrt(2) ratio 2.csv')
df3 = pd.read_csv('accuracy patient zsqrt(2) ratio 3.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 4.csv')
df5 = pd.read_csv('accuracy patient zsqrt(2) ratio 5.csv')

exact_accuracy_sparse_z4 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0], df5['sparse'][0] ]
almost_accuracy_sparse_z4 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1], df5['sparse'][1] ]

exact_accuracy_mid_z4 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0], df5['mid'][0] ]
almost_accuracy_mid_z4 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1], df5['mid'][1] ]

exact_accuracy_dense_z4 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0], df5['dense'][0] ]
almost_accuracy_dense_z4 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1], df5['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z4)
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z4)
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z4)
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z4)
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z4)
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z4)

axis[0, 1].set_xlabel('ratio patients/docteurs')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('ratio patients/docteurs')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction du ratio (z = sqrt(2))')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction du ratio (z = sqrt(2))')

# %%
figure, axis = plt.subplots(2, 3, figsize=(16, 8))

axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z1, label = 'z = 0.4')
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z2, label = 'z = 0.7')
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z3, label = 'z = 1.1')
axis[0, 0].plot([1, 2, 3, 4, 5], exact_accuracy_sparse_z4, label = 'z = sqrt(2)')

axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z1, label = 'z = 0.4')
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z2, label = 'z = 0.7')
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z3, label = 'z = 1.1')
axis[0, 1].plot([1, 2, 3, 4, 5], exact_accuracy_mid_z4, label = 'z = sqrt(2)')

axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z1, label = 'z = 0.4')
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z2, label = 'z = 0.7')
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z3, label = 'z = 1.1')
axis[0, 2].plot([1, 2, 3, 4, 5], exact_accuracy_dense_z4, label = 'z = sqrt(2)')


axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z1, label = 'z = 0.4')
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z2, label = 'z = 0.7')
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z3, label = 'z = 1.1')
axis[1, 0].plot([1, 2, 3, 4, 5], almost_accuracy_sparse_z4, label = 'z = sqrt(2)')

axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z1, label = 'z = 0.4')
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z2, label = 'z = 0.7')
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z3, label = 'z = 1.1')
axis[1, 1].plot([1, 2, 3, 4, 5], almost_accuracy_mid_z4, label = 'z = sqrt(2)')

axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z1, label = 'z = 0.4')
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z2, label = 'z = 0.7')
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z3, label = 'z = 1.1')
axis[1, 2].plot([1, 2, 3, 4, 5], almost_accuracy_dense_z4, label = 'z = sqrt(2)')

axis[0, 1].set_xlabel('ratio patients/docteurs')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('ratio patients/docteurs')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

axis[0, 0].legend()
axis[0, 1].legend()
axis[0, 2].legend()
axis[1, 0].legend()
axis[1, 1].legend()
axis[1, 2].legend()

plt.suptitle('Accuracy en fonction du ratio')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction du ratio')

# %% [markdown]
# ### Ratio fixe

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 1.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 1.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 1.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 1.csv')

exact_accuracy_sparse_r1 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0] ]
almost_accuracy_sparse_r1 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1] ]

exact_accuracy_mid_r1 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0] ]
almost_accuracy_mid_r1 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1] ]

exact_accuracy_dense_r1 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0] ]
almost_accuracy_dense_r1 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r1)
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r1)
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r1)
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r1)
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r1)
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r1)

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction de la distance (ratio = 1)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance (ratio = 1)')

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 2.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 2.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 2.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 2.csv')

exact_accuracy_sparse_r2 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0] ]
almost_accuracy_sparse_r2 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1] ]

exact_accuracy_mid_r2 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0] ]
almost_accuracy_mid_r2 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1] ]

exact_accuracy_dense_r2 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0] ]
almost_accuracy_dense_r2 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r2)
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r2)
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r2)
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r2)
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r2)
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r2)

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction de la distance (ratio = 2)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance (ratio = 2)')

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 3.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 3.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 3.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 3.csv')

exact_accuracy_sparse_r3 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0] ]
almost_accuracy_sparse_r3 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1] ]

exact_accuracy_mid_r3 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0] ]
almost_accuracy_mid_r3 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1] ]

exact_accuracy_dense_r3 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0] ]
almost_accuracy_dense_r3 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r3)
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r3)
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r3)
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r3)
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r3)
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r3)

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction de la distance (ratio = 3)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance (ratio = 3)')

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 4.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 4.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 4.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 4.csv')

exact_accuracy_sparse_r4 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0] ]
almost_accuracy_sparse_r4 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1] ]

exact_accuracy_mid_r4 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0] ]
almost_accuracy_mid_r4 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1] ]

exact_accuracy_dense_r4 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0] ]
almost_accuracy_dense_r4 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r4)
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r4)
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r4)
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r4)
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r4)
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r4)

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction de la distance (ratio = 4)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance (ratio = 4)')

# %%
df1 = pd.read_csv('accuracy patient z0.4 ratio 5.csv')
df2 = pd.read_csv('accuracy patient z0.7 ratio 5.csv')
df3 = pd.read_csv('accuracy patient z1.1 ratio 5.csv')
df4 = pd.read_csv('accuracy patient zsqrt(2) ratio 5.csv')

exact_accuracy_sparse_r5 = [ df1['sparse'][0], df2['sparse'][0], df3['sparse'][0], df4['sparse'][0] ]
almost_accuracy_sparse_r5 = [ df1['sparse'][1], df2['sparse'][1], df3['sparse'][1], df4['sparse'][1] ]

exact_accuracy_mid_r5 = [ df1['mid'][0], df2['mid'][0], df3['mid'][0], df4['mid'][0] ]
almost_accuracy_mid_r5 = [ df1['mid'][1], df2['mid'][1], df3['mid'][1], df4['mid'][1] ]

exact_accuracy_dense_r5 = [ df1['dense'][0], df2['dense'][0], df3['dense'][0], df4['dense'][0] ]
almost_accuracy_dense_r5 = [ df1['dense'][1], df2['dense'][1], df3['dense'][1], df4['dense'][1] ]

figure, axis = plt.subplots(2, 3, figsize=(16, 8))
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r5)
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r5)
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r5)
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r5)
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r5)
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r5)

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

plt.suptitle('Accuracy en fonction de la distance (ratio = 5)')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance (ratio = 5)')

# %%
figure, axis = plt.subplots(2, 3, figsize=(16, 8))

# axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r1, label = 'ratio 1')
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r2, label = 'ratio 2')
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r3, label = 'ratio 3')
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r4, label = 'ratio 4')
axis[0, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_sparse_r5, label = 'ratio 5')

# axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r1, label = 'ratio 1')
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r2, label = 'ratio 2')
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r3, label = 'ratio 3')
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r4, label = 'ratio 4')
axis[0, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_mid_r5, label = 'ratio 5')

# axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r1, label = 'ratio 1')
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r2, label = 'ratio 2')
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r3, label = 'ratio 3')
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r4, label = 'ratio 4')
axis[0, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], exact_accuracy_dense_r5, label = 'ratio 5')

# axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r1, label = 'ratio 1')
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r2, label = 'ratio 2')
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r3, label = 'ratio 3')
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r4, label = 'ratio 4')
axis[1, 0].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_sparse_r5, label = 'ratio 5')

# axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r1, label = 'ratio 1')
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r2, label = 'ratio 2')
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r3, label = 'ratio 3')
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r4, label = 'ratio 4')
axis[1, 1].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_mid_r5, label = 'ratio 5')

# axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r1, label = 'ratio 1')
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r2, label = 'ratio 2')
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r3, label = 'ratio 3')
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r4, label = 'ratio 4')
axis[1, 2].plot([0.4, 0.7, 1.1, np.sqrt(2)], almost_accuracy_dense_r5, label = 'ratio 5')

axis[0, 1].set_xlabel('distance z')
axis[0, 0].set_ylabel('exact accuracy')
axis[0, 0].set_title('sparse')
axis[0, 1].set_title('mid')
axis[0, 2].set_title('dense')

axis[1, 1].set_xlabel('distance z')
axis[1, 0].set_ylabel('almost accuracy')
axis[1, 0].set_title('sparse')
axis[1, 1].set_title('mid')
axis[1, 2].set_title('dense')

axis[0, 0].legend()
axis[0, 1].legend()
axis[0, 2].legend()
axis[1, 0].legend()
axis[1, 1].legend()
axis[1, 2].legend()

plt.suptitle('Accuracy en fonction de la distance')
# Out:
# Text(0.5, 0.98, 'Accuracy en fonction de la distance')
